# %% [markdown]
# <a href="https://colab.research.google.com/github/yyang201-creator/ELEC576-IDE-Project/blob/main/task6_ide_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet(name):
    return f"Hello, {name}! ELEC 576."

print(greet("yidi"))
# Out:
# Hello, yidi! ELEC 576.
